# %%
import requests
import pandas as pd
from pymongo import MongoClient
# Importer le module MySQLdb
import MySQLdb
from cassandra.cluster import Cluster

# %%
def extract():
    print("Extract..")
    url_st1 = "https://airqino-api.magentalab.it/v3/getStationHourlyAvg/283164601"
    url_st2 = "https://airqino-api.magentalab.it/v3/getStationHourlyAvg/283181971"

    print("Recuperation station1..")
    response_st1 = requests.get(url_st1)
    print("Recuperation station2..")
    response_st2 = requests.get(url_st2)

    print("Verif..")

    if response_st1.status_code == 200 and response_st2.status_code == 200:
        data_st1 = response_st1.json()
        data_st2 = response_st2.json()

        station1_df = pd.DataFrame(data_st1['data'])
        station1_df['sensor'] = data_st1['header']['station_name']
        station2_df = pd.DataFrame(data_st2['data'])
        station2_df['sensor'] = data_st2['header']['station_name']
        print("Df créés.")

        return station1_df, station2_df
    return None

# %%
def transform():
    station1, station2 = extract()
    
    print("Transform..")

    # Convertir la colonne 'timestamp' en datetime
    station1['timestamp'] = pd.to_datetime(station1['timestamp'])
    station2['timestamp'] = pd.to_datetime(station2['timestamp'])

    station1['date'] = pd.to_datetime(station1['timestamp'].dt.date)
    station2['date'] = pd.to_datetime(station2['timestamp'].dt.date)

    print("Calcul de moyennes..")

    # Calculer la moyenne journalière de CO et PM2.5
    daily_avg_st1 = station1.groupby('date')[['CO', 'PM2.5']].mean().reset_index()
    daily_avg_st2 = station2.groupby('date')[['CO', 'PM2.5']].mean().reset_index()

    daily_avg_st1['sensor'] = station1['sensor']
    daily_avg_st2['sensor'] = station2['sensor']
    print("Terminé")

    return daily_avg_st1, daily_avg_st2

# %%
def transform_for_mysql():
    station1, station2 = extract()
    print("Transform..")
    station1['timestamp'] = pd.to_datetime(station1['timestamp'])
    station2['timestamp'] = pd.to_datetime(station2['timestamp'])

    station1.rename(columns={"timestamp": "date"},inplace = True)
    station2.rename(columns={"timestamp": "date"},inplace = True)

    station1['sensor'] = 'SMART188'
    station2['sensor'] = 'SMART189'

    daily_avg_st1 = station1[['date', 'sensor', 'CO', 'PM2.5']]
    daily_avg_st2 = station2[['date', 'sensor', 'CO', 'PM2.5']]

    print("Terminé")

    return daily_avg_st1, daily_avg_st2

# %%
def load_in_mongo():
    station1, station2 = transform()
    print("Transform..")

    print("Conection to mongo database..")

    client = MongoClient('localhost', 27017)
    db = client['sensors_data']
    collection = db['data']

    print("To_dict")

    station1_dict = station1.to_dict("records")
    station2_dict = station2.to_dict("records")

    print("Loading..")
    # Pour chaque document, vérifier s'il existe déjà dans la collection
    # Si non, insérer le document avec la méthode insert_one()
    # Sinon, passer au document suivant
    for doc in station1_dict + station2_dict:
        # On peut utiliser les champs date et sensor comme critère de recherche
        # On crée un dictionnaire avec ces deux clés et leurs valeurs
        query = {"date": doc["date"], "sensor": doc["sensor"]}
        # On utilise la méthode find_one() pour chercher le document par sa date et son sensor
        # Si le résultat est None, cela signifie que le document n'existe pas
        if collection.find_one(query) is None:
            # On insère le document avec la méthode insert_one()
            collection.insert_one(doc)
            print(f"Inserted document with date {doc['date']} and sensor {doc['sensor']}")
        else:
            # On passe au document suivant
            print(f"Document with date {doc['date']} and sensor {doc['sensor']} already exists")
    print("Ok")

# %%
def load_in_cassandra():
    station1, station2 = transform()
    print("Transform..")

    print("Connection to cassandra cluster..")

    # On crée un objet Cluster qui représente le cluster Cassandra
    # On peut spécifier les adresses des nœuds du cluster dans le paramètre contact_points
    cluster = Cluster(contact_points=['localhost'], port=9042)
    # On crée un objet Session qui permet d'exécuter des requêtes CQL
    session = cluster.connect('sensors_data')
    # On se connecte à l'espace de clés sensors_data
    session.set_keyspace('data')

    print("To_dict")

    station1_dict = station1.to_dict("records")
    station2_dict = station2.to_dict("records")

    print("Loading..")
    # Pour chaque document, vérifier s'il existe déjà dans la famille de colonnes data
    # Si non, insérer le document avec la méthode execute()
    # Sinon, passer au document suivant
    for doc in station1_dict + station2_dict:
        # On peut utiliser les champs date et sensor comme critère de recherche
        # On crée une requête CQL avec ces deux clés et leurs valeurs
        query = f"SELECT * FROM data WHERE date = '{doc['date']}' AND sensor = '{doc['sensor']}'"
        # On utilise la méthode execute() pour exécuter la requête CQL
        # Si le résultat est vide, cela signifie que le document n'existe pas
        if not session.execute(query):
            # On crée une requête CQL pour insérer le document
            # On utilise la méthode format() pour remplacer les valeurs des champs
            insert_query = f"INSERT INTO data (date, sensor, PM2_5, CO) VALUES ('{doc['date']}', '{doc['sensor']}', {doc['PM2_5']}, {doc['CO']})"
            # On exécute la requête CQL avec la méthode execute()
            session.execute(insert_query)
            print(f"Inserted document with date {doc['date']} and sensor {doc['sensor']}")
        else:
            # On passe au document suivant
            print(f"Document with date {doc['date']} and sensor {doc['sensor']} already exists")
    print("Ok")

# %%
def load_in_mysql():
    station1, station2 = transform()
    print("Connection to database..")
    conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="sensors_data")
    cursor = conn.cursor()

    print("To_dict")

    station1_dict = station1.to_dict("records")
    station2_dict = station2.to_dict("records")

    print("Loading..")
    for row in station1_dict:
        sql = "INSERT INTO data (`date`, `sensor`, `PM2_5`, `CO`) VALUES (%s, %s, %s, %s)"
        val = (row["date"], row['sensor'], row["PM2.5"], row["CO"])
        cursor.execute("SELECT * FROM data WHERE `date` = %s and `sensor` = %s", (row["date"], row['sensor']))
        if cursor.rowcount == 0:
            cursor.execute(sql, val)
            conn.commit()

    for row in station2_dict:
        sql = "INSERT INTO data (`date`, `sensor`, `PM2_5`, `CO`) VALUES (%s, %s, %s, %s)"
        val = (row["date"], row['sensor'], row["PM2.5"], row["CO"])
        cursor.execute("SELECT * FROM data WHERE `date` = %s and `sensor` = %s", (row["date"], row['sensor']))
        if cursor.rowcount == 0:
            cursor.execute(sql, val)
            conn.commit()

    print("Ok")
    conn.close()

# %%
load_in_mysql()
# Out:
# Extract..
# Recuperation station1..
# Recuperation station2..
# Verif..
# Df créés.
# Transform..
# Calcul de moyennes..
# Terminé
# Connection to database..
# To_dict
# Loading..
# Ok

# %%
load_in_mongo()
# Out:
# Extract..
# Recuperation station1..
# Recuperation station2..
# Verif..
# Df créés.
# Transform..
# Calcul de moyennes..
# Terminé
# Transform..
# Conection to mongo database..
# To_dict
# Loading..
# Document with date 2022-12-11 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-12 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-13 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-14 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-15 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-16 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-17 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-18 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-19 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-20 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-21 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-22 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-23 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-24 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-25 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-26 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-27 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-28 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-29 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-30 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-31 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-01-31 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-02-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-03-31 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-04-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-05-31 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-06-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-07-31 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-08-31 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-09-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-10-31 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-11 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-12 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-13 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-14 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-15 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-16 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-17 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-18 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-19 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-20 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-21 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-22 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-23 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-24 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-25 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-26 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-27 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-28 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-29 00:00:00 and sensor SMART188 already exists
# Document with date 2023-11-30 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-01 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-02 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-03 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-04 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-05 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-06 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-07 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-08 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-09 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-10 00:00:00 and sensor SMART188 already exists
# Document with date 2023-12-11 00:00:00 and sensor SMART188 already exists
# Document with date 2022-12-11 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-12 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-13 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-14 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-15 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-16 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-17 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-18 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-19 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-20 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-21 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-22 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-23 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-24 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-25 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-26 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-27 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-28 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-29 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-30 00:00:00 and sensor SMART189 already exists
# Document with date 2022-12-31 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-01-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-02-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-03-31 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-04-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-05-31 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-06-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-07-31 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-08-31 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-09-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-10-31 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-11 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-12 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-13 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-14 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-15 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-16 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-17 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-18 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-19 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-20 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-21 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-22 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-23 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-24 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-25 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-26 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-27 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-28 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-29 00:00:00 and sensor SMART189 already exists
# Document with date 2023-11-30 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-01 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-02 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-03 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-04 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-05 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-06 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-07 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-08 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-09 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-10 00:00:00 and sensor SMART189 already exists
# Document with date 2023-12-11 00:00:00 and sensor SMART189 already exists
# Ok

# %%
load_in_cassandra()
